# %% [markdown]
# # **Shooter Model**
# ## An XGBoostRegressor Model to predict the ranking (by Rach and Kelly) of an incoming new alcohol:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from telnetlib import GA
import sklearn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score, accuracy_score, f1_score, mean_absolute_percentage_error
from xgboost import XGBRegressor

# %% [markdown]
# ***

# %% [markdown]
# ### **Process:**
# ### Compilation of the shooter csv into a pandas df:

# %%
df = pd.read_csv('curr_alcs.csv')
df['alc_percentage'] = df['alc_percentage'].astype(float)
df['if_sweet'] = df['if_sweet'].astype(bool)
df['if_fruit_on_bottle'] = df['if_fruit_on_bottle'].astype(bool)
df['if_citrus'] = df['if_citrus'].astype(bool)
df['shooter_plastic'] = df['shooter_plastic'].astype(bool)
df.head()
# Out:
#    rank                     name  alc_percentage  if_sweet  \
# 0     1                kinky red            0.17      True
# 1     2               kinky pink            0.17      True
# 2     3       smirnoff raspberry            0.35      True
# 3     4  smirnoff peach lemonade            0.35      True
# 4     5   smirnoff pink lemonade            0.35      True
#
#    if_fruit_on_bottle  if_citrus  shooter_plastic   type   color     brand
# 0                True      False             True  vodka     red     kinky
# 1                True       True             True  vodka     red     kinky
# 2                True      False             True  vodka   clear  smirnoff
# 3                True       True             True  vodka  orange  smirnoff
# 4                True       True             True  vodka     red  smirnoff

# %% [markdown]
# ### One-Hot Encoding of type, color and brand:

# %%
df = pd.get_dummies(data=df, columns=['type', 'brand', 'color'], dtype=bool)
df.head()
# Out:
#    rank                     name  alc_percentage  if_sweet  \
# 0     1                kinky red            0.17      True
# 1     2               kinky pink            0.17      True
# 2     3       smirnoff raspberry            0.35      True
# 3     4  smirnoff peach lemonade            0.35      True
# 4     5   smirnoff pink lemonade            0.35      True
#
#    if_fruit_on_bottle  if_citrus  shooter_plastic  type_gin  type_liqueur  \
# 0                True      False             True     False         False
# 1                True       True             True     False         False
# 2                True      False             True     False         False
# 3                True       True             True     False         False
# 4                True       True             True     False         False
#
#    type_moonshine  ...  brand_southern_comfort  brand_stoli  color_black  \
# 0           False  ...                   False        False        False
# 1           False  ...                   False        False        False
# 2           False  ...                   False        False        False
# 3           False  ...                   False        False        False
# 4           False  ...                   False        False        False
#
#    color_blue  color_brown  color_clear  color_green  color_orange  \
# 0       False        False        False        False         False
# 1       False        False        False        False         False
# 2       False        False         True        False         False
# 3       False        False        False        False          True
# 4       False        False        False        False         False
#
#    color_purple  color_red
# 0         False       True
# 1         False       True
# 2         False      False
# 3         False      False
# 4         False       True
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Prep the data for XGBoost Model:

# %%
df = df.drop(['name'], axis=1)
features = df.dtypes[(df.columns != 'rank')].index # Grab all features except that which we are trying to predict

# %%
print("split it fully...");
X_train, X_test, y_train, y_test = train_test_split(df[features], df['rank'], test_size=0.2, random_state=40)
# Out:
# split it fully...

# %%
print("creating the model...")
model = XGBRegressor(colsample_bytree=0.3, gamma=0, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.6)
# model = XGBRegressor()
# Out:
# creating the model...

# %%
model.fit(X_train, y_train)
print("- predicting...")
y_pred = model.predict(X_test)
# Out:
# - predicting...

# %%
score = r2_score(y_test, y_pred)
print("model predicted r2:", score)
# Out:
# model predicted r2: -0.2273768132588263

# %%
X_test.head()
# Out:
#     alc_percentage  if_sweet  if_fruit_on_bottle  if_citrus  shooter_plastic  \
# 2             0.35      True                True      False             True
# 16            0.40     False               False      False             True
# 19            0.35      True               False      False            False
# 14            0.40     False               False      False             True
# 15            0.40     False               False      False             True
#
#     type_gin  type_liqueur  type_moonshine  type_rum  type_tequila  ...  \
# 2      False         False           False     False         False  ...
# 16     False         False           False     False          True  ...
# 19     False          True           False     False         False  ...
# 14     False         False           False     False          True  ...
# 15     False         False           False     False          True  ...
#
#     brand_southern_comfort  brand_stoli  color_black  color_blue  color_brown  \
# 2                    False        False        False       False        False
# 16                   False        False        False       False         True
# 19                   False        False         True       False        False
# 14                   False        False        False       False        False
# 15                   False        False        False       False        False
#
#     color_clear  color_green  color_orange  color_purple  color_red
# 2          True        False         False         False      False
# 16        False        False         False         False      False
# 19        False        False         False         False      False
# 14         True        False         False         False      False
# 15         True        False         False         False      False
#
# [5 rows x 37 columns]

# %%
newdf = df.copy()
newdf.head()
# Out:
#    rank  alc_percentage  if_sweet  if_fruit_on_bottle  if_citrus  \
# 0     1            0.17      True                True      False
# 1     2            0.17      True                True       True
# 2     3            0.35      True                True      False
# 3     4            0.35      True                True       True
# 4     5            0.35      True                True       True
#
#    shooter_plastic  type_gin  type_liqueur  type_moonshine  type_rum  ...  \
# 0             True     False         False           False     False  ...
# 1             True     False         False           False     False  ...
# 2             True     False         False           False     False  ...
# 3             True     False         False           False     False  ...
# 4             True     False         False           False     False  ...
#
#    brand_southern_comfort  brand_stoli  color_black  color_blue  color_brown  \
# 0                   False        False        False       False        False
# 1                   False        False        False       False        False
# 2                   False        False        False       False        False
# 3                   False        False        False       False        False
# 4                   False        False        False       False        False
#
#    color_clear  color_green  color_orange  color_purple  color_red
# 0        False        False         False         False       True
# 1        False        False         False         False       True
# 2         True        False         False         False      False
# 3        False        False          True         False      False
# 4        False        False         False         False       True
#
# [5 rows x 38 columns]

# %%
raw_df = pd.read_csv('alcs_w_new.csv')
df = raw_df.drop(['id'], axis = 1)
df['alc_percentage'] = df['alc_percentage'].astype(float)
df['if_sweet'] = df['if_sweet'].astype(bool)
df['if_fruit_on_bottle'] = df['if_fruit_on_bottle'].astype(bool)
df['if_citrus'] = df['if_citrus'].astype(bool)
df['shooter_plastic'] = df['shooter_plastic'].astype(bool)
df = pd.get_dummies(data=df, columns=['type', 'brand', 'color'], dtype=bool)
df.head()
# Out:
#    rank                     name  alc_percentage  if_sweet  \
# 0   1.0               kinky pink            0.17      True
# 1   2.0       smirnoff raspberry            0.35      True
# 2   3.0  smirnoff peach lemonade            0.35      True
# 3   4.0   smirnoff pink lemonade            0.35      True
# 4   5.0              kinky aloha            0.17      True
#
#    if_fruit_on_bottle  if_citrus  shooter_plastic  type_gin  type_liqueur  \
# 0                True       True             True     False         False
# 1                True      False             True     False         False
# 2                True       True             True     False         False
# 3                True       True             True     False         False
# 4                True       True             True     False         False
#
#    type_moonshine  ...  brand_southern_comfort  brand_stoli  color_black  \
# 0           False  ...                   False        False        False
# 1           False  ...                   False        False        False
# 2           False  ...                   False        False        False
# 3           False  ...                   False        False        False
# 4           False  ...                   False        False        False
#
#    color_blue  color_brown  color_clear  color_green  color_orange  \
# 0       False        False        False        False         False
# 1       False        False         True        False         False
# 2       False        False        False        False          True
# 3       False        False        False        False         False
# 4       False        False         True        False         False
#
#    color_purple  color_red
# 0         False       True
# 1         False      False
# 2         False      False
# 3         False       True
# 4         False      False
#
# [5 rows x 39 columns]

# %%
examined = (df.iloc[-1:])
examined.head()
# Out:
#     rank       name  alc_percentage  if_sweet  if_fruit_on_bottle  if_citrus  \
# 26   NaN  kinky red            0.17      True                True      False
#
#     shooter_plastic  type_gin  type_liqueur  type_moonshine  ...  \
# 26             True     False         False           False  ...
#
#     brand_southern_comfort  brand_stoli  color_black  color_blue  color_brown  \
# 26                   False        False        False       False        False
#
#     color_clear  color_green  color_orange  color_purple  color_red
# 26        False        False         False         False       True
#
# [1 rows x 39 columns]

# %%
examined = examined.drop(['name', 'rank'], axis=1)
examined.head()
# Out:
#     alc_percentage  if_sweet  if_fruit_on_bottle  if_citrus  shooter_plastic  \
# 26            0.17      True                True      False             True
#
#     type_gin  type_liqueur  type_moonshine  type_rum  type_tequila  ...  \
# 26     False         False           False     False         False  ...
#
#     brand_southern_comfort  brand_stoli  color_black  color_blue  color_brown  \
# 26                   False        False        False       False        False
#
#     color_clear  color_green  color_orange  color_purple  color_red
# 26        False        False         False         False       True
#
# [1 rows x 37 columns]

# %%
predicted = model.predict(examined)
print("prediction ranking: #", int(round(predicted[0], 0)), sep='')
# Out:
# prediction ranking: #2
